# %% [markdown]
# ![](triangle.gif)

# %%
import turtle
import math

t = turtle.Turtle()

def draw_isosceles(t, a, l):
    t.left(math.radians(a))
    b = 80
    t.forward(l)
    t.right(math.radians(b))
    t.forward(30.9)
    t.right(math.radians(b))
    t.forward(l)

def draw_triangle(t, opposite, adjacent):
    t.forward(opposite)
    t.left(90)
    t.forward(adjacent)
    t.left()


draw_isosceles(t, 20, 88.9)
t.done()

t.screen.exitonclick()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 23
#      19     t.left()
#      22 draw_isosceles(t, 20, 88.9)
# ---> 23 t.done()
#      25 t.screen.exitonclick()
#
# AttributeError: 'Turtle' object has no attribute 'done'

# %%
import math

# %%
from turtle import *
import math
import random

title('Isosceles Triangle Circle - PythonTurtle.Academy')
setup(1000,1000)
hideturtle()
setworldcoordinates(-500,-500,500,500)
hideturtle()
tracer(0,0)

# x,y is the center of the base, width: length of base, height: height of triangle from the top to base
# direction:direction from the center of base to top
def IsoscelesTriangle(x,y,width,height,direction,c):
    up()
    goto(x,y)
    seth(direction-90)
    fd(width/2)
    p1x, p1y = xcor(), ycor() # first point: bottom right
    back(width)
    p2x, p2y = xcor(), ycor() # second point: bottom left
    goto(x,y)
    seth(direction)
    fd(height)
    p3x, p3y = xcor(), ycor() # third point: top
    goto(p1x,p1y)
    down()
    fillcolor(c)
    begin_fill()
    goto(p2x,p2y)
    goto(p3x,p3y)
    goto(p1x,p1y)
    end_fill()

# n=12
# r=300
# width=2*r*math.sin(math.radians(180/n))
    
IsoscelesTriangle(0, 0, 30.9, 88.9, 0, "blue")
# height=200
# for i in range(n):    
#     IsoscelesTriangle(r*math.cos(math.radians(180/n))*math.cos(math.radians(i*360/n)),
#                       r*math.cos(math.radians(180/n))*math.sin(math.radians(i*360/n)),width,height,i*360/n,'blue')
    
update()

# %%
import math
#            C
#            /\
#           /  \
#          /    \
#         /      \
#      b /        \ a
#       /          \ 
#      /     |      \
#     /      |       \
#    /       |        \
#   /        | h       \
# A --------------------  B
#             c

# a = ?
# h = ? 
# sah coa toh
b = a = 88.9  # length of the long sides if a 2x4 on 4" edge
b = a = 25.4 * 1.5 # length of sides if a 2x4 on 2" side
C = 20  # degrees for angle C
A = B = (180 - C)/2

# Area = 1/2 b h = 1/2 a b (sin C)

# c = √b2 + a2 - 2ba·cos(C)
c = math.sqrt(b**2 + a**2 - (2 * b * a * math.cos(math.radians(C))))
print(f"{c=}")
area = 0.5 * a * b * math.sin(math.radians(C))
print(f"{area=}")

ha = (2 * area) / a
hb = (2 * area) / b
hc = (2 * area) / c

print(f"{ha=} {hb=} {hc=}")
print(f"hb the simple way = {a * math.sin(math.radians(C))=}")

# the hb line is some amount away from angle A

ac = math.cos(math.radians(A)) * hb
print(f"{ac=}")
# Out:
# c=13.231991138220078
# area=248.2399301264869
# ha=13.030967460707977 hb=13.030967460707977 hc=37.521175389765155
# hb the simple way = a * math.sin(math.radians(C))=13.030967460707975
# ac=2.262803752789008
